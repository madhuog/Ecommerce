# %%
from tabulate import tabulate

etemp=[]
ftemp=[]
stemp=[]
total_amt=[]
total=0
item_num=0
s_quant=0
f_quant=0
e_quant=0
#----------------------------BILL-----------------------------------------------------

def bill():
    fashion_total=0
    electronics_total=0
    sports_total=0
    print('\n\n\n')
    print(('BILL RECEIPT').center(60,'-'))
    print('\n----------------------Electronics Bill-------------------------------')
    for i in electronic_price:
        electronics_total+=i
    etemp.append(['SubTotal','','',e_quant,'',electronics_total])
    print(tabulate(etemp,headers=['Item name','Brand','Model','Quantity','Price','Amount']))
    print('\n----------------------Fashion Bill-------------------------------')
    for i in fashion_price:
        fashion_total+=i
    ftemp.append(['SubTotal','','',f_quant,'',fashion_total])
    print(tabulate(ftemp,headers=['Category','Item name','Size','Quantity','Price','Amount']))
    print('\n----------------------Sports Bill-------------------------------')
    for i in sports_price:
        sports_total+=i
    stemp.append(['SubTotal','','',s_quant,'',sports_total])
    print(tabulate(stemp,headers=['Item Name','Size','Type','Quantity','Price','Amount']))
    print('\n------------------------Total Bill-------------------------------')
    total=fashion_total+sports_total+electronics_total
    print('\nTotal                                                {}'.format(total))
    print('\n\n')
    print(('Thank You').center(60,'*'))
    
          
        
#----------------------------CART------------------------------------------------------

def cart():
        print('\n\n\n')
        print(("WISHLIST").center(100,'*'))
        print('\n\n')
        print("----------Electronics-----------")
        print(tabulate(etemp,headers=['Item name','Brand','Model','Quantity','Price','Amount'])) 
        print('\n')
        print('------------Fashion----------------')
        print(tabulate(ftemp,headers=['Category','Item name','Size','Quantity','Price','Amount']))
        print('\n')
        print('-------------Sports----------------')
        print(tabulate(stemp,headers=['Item Name','Size','Type','Quantity','Price','Amount']))
        print('\n\n\n')
        c=0
        while c==0:
            s=input('\nWould you like to purchase more items(Y/N):')
            if s.isalpha() and (s=='Y' or s=='y'):
                main()
                c=1
            elif s.isalpha() and (s=='N' or s=='n'):
                d=0
                c=1
                while d==0:
                    s=input('\nWould you like to bill the items(Y/N):')
                    if s.isalpha() and (s=='Y' or s=='y'):
                        bill()
                        d=1
                    elif s.isalpha() and (s=='N' or s=="n"):
                        main()
                        d=1
                    else:
                        print('\nInvalid choice')
            else:
                print('\nInvalid choice')
            


#----------------------------SPORTS----------------------------------------------------------

sports_price=[]

def sports():
    global s_quant
    print("\n.....SPORTS.....")
    print("\nPlease select the items")
    print('\n1.Cricket Bat\n2.Cricket Ball\n3.Volley Ball\n4.Foot Ball')
    z=input()
    
 #--------------CRICKET_BAT------------------------------------------------------------------
    if z=='1':
        price=[['S',250],['M',500],['L',800]]
        print("\nPlease select size")
        print('1.Small\n2.Medium\n3.Large')
        y=input()
        
        
        if y=='1':
            print("\nYou selected Cricket Bat of size 'S'")
            print('Rs.',price[0][1])
            d=0
            while d==0:
                q=input("\nPlease select the number of pieces(quantity):")
                if q.isnumeric():
                    q=int(q)
                    s_quant+=q
                    d=1
                else:
                    print('\nInvalid input')
            total_s=q*(price[0][1])
            sports_price.append(total_s)
            stemp.append(['cricket bat','s','',q,price[0][1],total_s])
            c=0
            while c==0:
                s = input("\nWould you like to purchase more sports items?..Y/N:")
                if s.isalpha() and (s=='Y' or s=='y'):
                    sports()
                    c=1
                elif s.isalpha() and (s=='N' or s=='n'):
                    main()
                    c=1
                else:
                    print('\nInvalid input')
                
        elif y=='2':
            print("\nYou selected Cricket Bat of size 'M'")
            print('Rs.',price[1][1])
            d=0
            while d==0:
                q=input("\nPlease select the number of pieces(quantity):")
                if q.isnumeric():
                    q=int(q)
                    s_quant+=q
                    d=1
                else:
                    print('\nInvalid input')
            total_s=q*(price[1][1])
            sports_price.append(total_s)
            stemp.append(['cricket bat','M','',q,price[1][1],total_s])
            c=0
            while c==0:
                s = input("\nWould you like to purchase more sports items?..Y/N:")
                if s.isalpha() and (s=='Y' or s=='y'):
                    sports()
                    c=1
                elif s.isalpha() and (s=='N' or s=='n'):
                    main()
                    c=1
                else:
                    print('\nInvalid input')  
                
        elif y=='3':
            print("\nYou selected Cricket Bat of size 'L'")
            print('Rs.',price[2][1])
            d=0
            while d==0:
                q=input("\nPlease select the number of pieces(quantity):")
                if q.isnumeric():
                    q=int(q)
                    s_quant+=q
                    d=1
                else:
                    print('\nInvalid input')
            total_s=q*(price[2][1])
            sports_price.append(total_s)
            stemp.append(['cricket bat','L','',q,price[2][1],total_s])
            c=0
            while c==0:
                s = input("\nWould you like to purchase more sports items?..Y/N:")
                if s.isalpha() and (s=='Y' or s=='y'):
                    sports()
                    c=1
                elif s.isalpha() and (s=='N' or s=='n'):
                    main()
                    c=1
                else:
                    print('\nInvalid input')
        else:
            print("\nInvalid input")
            sports()
            
 #--------------CRICKET_BALL------------------------------------------------------------------
    if z=='2':
        price=[['Leather',250],['Tennies',50],['Rubber',80]]
        print("\nPlease select size")
        print('1.Leather\n2.Tennies\n3.Rubber')
        y=input()
        
        
        if y=='1':
            print("\nYou selected Cricket Ball of type leather")
            print('Rs.',price[0][1])
            d=0
            while d==0:
                q=input("\nPlease select the number of pieces(quantity):")
                if q.isnumeric():
                    q=int(q)
                    s_quant+=q
                    d=1
                else:
                    print('\nInvalid input')
            total_s=q*(price[0][1])
            sports_price.append(total_s)
            stemp.append(['cricket ball','','leather',q,price[0][1],total_s])
            c=0
            while c==0:
                s = input("\nWould you like to purchase more sports items?..Y/N:")
                if s.isalpha() and (s=='Y' or s=='y'):
                    sports()
                    c=1
                elif s.isalpha() and (s=='N' or s=='n'):
                    main()
                    c=1
                else:
                    print('\nInvalid input')
                
        elif y=='2':
            print("\nYou selected Cricket Ball of type tennies")
            print('Rs.',price[1][1])
            d=0
            while d==0:
                q=input("\nPlease select the number of pieces(quantity):")
                if q.isnumeric():
                    q=int(q)
                    s_quant+=q
                    d=1
                else:
                    print('\nInvalid input')
            total_s=q*(price[1][1])
            sports_price.append(total_s)
            stemp.append(['cricket ball','','tennies',q,price[1][1],total_s])
            c=0
            while c==0:
                s = input("\nWould you like to purchase more sports items?..Y/N:")
                if s.isalpha() and (s=='Y' or s=='y'):
                    sports()
                    c=1
                elif s.isalpha() and (s=='N' or s=='n'):
                    main()
                    c=1
                else:
                    print('\nInvalid input')  
                
        elif y=='3':
            print("\nYou selected Cricket Ball of type rubber")
            print('Rs.',price[2][1])
            d=0
            while d==0:
                q=input("\nPlease select the number of pieces(quantity):")
                if q.isnumeric():
                    q=int(q)
                    s_quant+=q
                    d=1
                else:
                    print('\nInvalid input')
            total_s=q*(price[2][1])
            sports_price.append(total_s)
            stemp.append(['cricket ball','','rubber',q,price[2][1],total_s])
            c=0
            while c==0:
                s = input("\nWould you like to purchase more sports items?..Y/N:")
                if s.isalpha() and (s=='Y' or s=='y'):
                    sports()
                    c=1
                elif s.isalpha() and (s=='N' or s=='n'):
                    main()
                    c=1
                else:
                    print('\nInvalid input')
        else:
            print("\nInvalid input")
            sports() 
            
   #--------------VALLEY BALL--------------------------------------------------------------
    elif z=='3':
        print("\nYou selected Valley Ball")
        print('Rs.400')
        d=0
        while d==0:
            q=input("\nPlease select the number of pieces(quantity):")
            if q.isnumeric():
                q=int(q)
                s_quant+=q
                d=1
            else:
                print('\nInvalid input')
        total_s=q*400
        sports_price.append(total_s)
        stemp.append(['valley ball','','',q,400,total_s])
        c=0
        while c==0:
            s = input("\nWould you like to purchase more sports items?..Y/N:")
            if s.isalpha() and (s=='Y' or s=='y'):
                sports()
                c=1
            elif s.isalpha() and (s=='N' or s=='n'):
                main()
                c=1
            else:
                print('\nInvalid input')          
   #--------------VALLEY BALL--------------------------------------------------------------
    elif z=='4':
        print("\nYou selected Foot Ball")
        print('Rs.500')
        d=0
        while d==0:
            q=input("\nPlease select the number of pieces(quantity):")
            if q.isnumeric():
                q=int(q)
                s_quant+=q
                d=1
            else:
                print('\nInvalid input')
        total_s=q*500
        sports_price.append(total_s)
        stemp.append(['foot ball','','',q,500,total_s])
        c=0
        while c==0:
            s = input("\nWould you like to purchase more sports items?..Y/N:")
            if s.isalpha() and (s=='Y' or s=='y'):
                sports()
                c=1
            elif s.isalpha() and (s=='N' or s=='n'):
                main()
                c=1
            else:
                print('\nInvalid input') 
            
    else:
        print("\nInvalid input")
        sports()
        
#----------------------------FASHION---------------------------------------------------------

fashion_price=[]

def fashion():
    global f_quant
    print("\n......FASHION.....")
    print("\nPlease select male/female")
    print("1.Male\n2.Female")
    z=input()
    
 #---------MALE-------------------------------------------------------------------------------
    if z=='1':
        print("\nPlease select")
        print("1.Shirt\n2.T-shrit\n3.Pant\n4.Jacket")
        y=input()
        
        if y=='1':
            print("\n....SHIRT....")
            price=[['S',250],['M',350],['L',500]]
            for i in price:
                print(i)
            print("\n....SIZE....")
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected Shirt of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['male','shirt','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                 
            elif a=='2':
                print("\nYou selected Shrit of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['male','shirt','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                    
            elif a=='3':
                print("\nYou selected Shrit of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['male','shirt','L',q,price[2][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')  
            else:
                print("\nInvalid input")
                fashion()
                
                
        elif y=='2':
            print("\n....T-SHIRT....")
            price=[['S',150],['M',250],['L',300]]
            for i in price:
                print(i)
            print("\n....SIZE....")
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected T-Shrit of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['male','t-shirt','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                 
            elif a=='2':
                print("\nYou selected T-Shrit of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['male','t-shirt','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                    
            elif a=='3':
                print("\nYou selected T-Shrit of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['male','t-shirt','L',q,price[2][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            else:
                print("\nInvalid input")
                fashion()
         
        elif y=='3':
            print("\n....PANT....")
            price=[['S',500],['M',850],['L',1100]]
            for i in price:
                print(i)
            print("\n....SIZE....")
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected pant of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['male','pant','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                 
            elif a=='2':
                print("\nYou selected pant of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['male','pant','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                    
            elif a=='3':
                print("\nYou selected pant of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['male','pant','L',q,total_price[2][1],f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            else:
                print("\nInvalid input")
                fashion()
                
              
        elif y=='4':
            print("\n....JACKET....")
            price=[['S',350],['M',700],['L',900]]
            for i in price:
                print(i)
            print('\n....SIZE....')
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected jacket of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['male','jacket','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            
                 
            elif a=='2':
                print("\nYou selected jacket of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['male','jacket','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            
                    
            elif a=='3':
                print("\nYou selected jacket of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['male','jacket','L',q,price[2][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            else:
                print("\nInvalid input")
                fashion()
                
  #---------FEMALE-------------------------------------------------------------------------------
    if z=='2':
        print("\nPlease select")
        print("1.Kurta\n2.T-shrit\n3.Pant\n4.Jacket")
        y=input()
        
        if y=='1':
            print("\n....Kurta....")
            price=[['S',250],['M',350],['L',500]]
            for i in price:
                print(i)
            print('\n....SIZE....')
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected Kurta of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['female','kurta','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                 
            elif a=='2':
                print("\nYou selected Kurta of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['female','Kurta','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                    
            elif a=='3':
                print("\nYou selected Kurta of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['female','Kurta','L',q,price[2][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')  
            else:
                print("\nInvalid input")
                fashion()
                
                
        elif y=='2':
            print("\n....T-SHIRT....")
            price=[['S',150],['M',250],['L',300]]
            for i in price:
                print(i)
            print('\n....SIZE....')
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected T-Shrit of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['female','t-shirt','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                 
            elif a=='2':
                print("\nYou selected T-Shrit of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['female','t-shirt','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                    
            elif a=='3':
                print("\nYou selected T-Shrit of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['female','t-shirt','L',q,price[2][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            else:
                print("\nInvalid input")
                fashion()
         
        elif y=='3':
            print("\n....PANT....")
            price=[['S',500],['M',850],['L',1100]]
            for i in price:
                print(i)
            print('\n....SIZE....')
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected pant of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['female','pant','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                 
            elif a=='2':
                print("\nYou selected pant of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['female','pant','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                    
            elif a=='3':
                print("\nYou selected pant of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['female','pant','L',q,price[2][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            else:
                print("\nInvalid input")
                fashion()
                
              
        elif y=='4':
            print("\n....JACKET....")
            price=[['S',350],['M',700],['L',900]]
            for i in price:
                print(i)
            print('\n....SIZE....')
            print('1.Small\n2.Medium\n3.Large')
            a=input("\nPlease select size:")
            
            if a=='1':
                print("\nYou selected jacket of size 'S'")
                print('Rs.',price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[0][1])
                fashion_price.append(total_f)
                ftemp.append(['female','jacket','S',q,price[0][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                 
            elif a=='2':
                print("\nYou selected jacket of size 'M'")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[1][1])
                fashion_price.append(total_f)
                ftemp.append(['female','jacket','M',q,price[1][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                    
            elif a=='3':
                print("\nYou selected jacket of size 'L'")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        f_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_f=q*(price[2][1])
                fashion_price.append(total_f)
                ftemp.append(['female','jacket','L',q,price[2][1],total_f])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more fashion items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        fashion()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
            else:
                print("\nInvalid input")
                fashion()   
    else:
        print("\nInvalid input")
        fashion()
                

#-------------------------ELECTRONICS---------------------------------------------------------
electronic_price=[]

def electronics():
    global e_quant
    print("\n.....ELECTRONICS.....")
    print("1.TV\n2.Mobile")
    z=input("\nPlease select item:")  
    
#---------------------------------------------TV----------------------------------------------

    if z=='1':
        print("\n....BRAND....")
        print("1.ONE PLUSE\n2.ONIDA\n3.SAMSUNG\n4.LG")
        y=input("\nPlease select the brand:")
        
    #------ONE_PLUSE TV------------------------------------------------------------------------

        if y=='1':
            print("\n....ONE PLUSE....")
            price=[['15-inch',15000],['32-inch',25000],['55-inch',50000]]
            for i in price:
                print(i)
            print("\n1. 15-inch",'2. 32-inch','3. 55-inch',sep='\n')
            a=input("Select the size of One Pluse:")
            if a=='1':
                print("\nYou have selected 15-inch One Pluse TV")
                print("Rs.",price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')    
                total_e=q*(price[0][1])
                electronic_price.append(total_e)
                etemp.append(['TV','One Pluse','15-inch',q,price[0][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                        
                                
            elif a=='2':
                print("\nYou have selected 32-inch One Pluse TV")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[1][1])
                electronic_price.append(total_e)
                etemp.append(['TV','One Pluse','32-inch',q,price[1][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='3':
                print("\nYou have selected 55-inch One Pluse TV")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[2][1])
                electronic_price.append(total_e)
                etemp.append(['TV','One Pluse','55-inch',q,price[2][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
            else:
                print("\nInvalid choice")
                electronics()
    
      #----------ONIDA TV---------------------------------------------------------------          
                    
        elif y=='2':
            print("\n....ONIDA....")
            price=[['18-inch',13000],['34-inch',28000],['50-inch',40000]]
            for i in price:
                print(i)
            print("\n1. 18-inch",'2. 34-inch','3. 50-inch',sep='\n')
            a=input("Select the size of ONIDA tv")
            if a=='1':
                print("\nYou have selected 18-inch Onida TV")
                print("Rs.",price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[0][1])
                electronic_price.append(total_e)
                etemp.append(['TV','Onida','18-inch',q,price[0][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
                    
            elif a=='2':
                print("\nYou have selected 34-inch Onida TV")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[1][1])
                electronic_price.append(total_e)
                etemp.append(['TV','Onida','34-inch',q,price[1][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='3':
                print("\nYou have selected 50-inch Onida TV")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[2][1])
                electronic_price.append(total_e)
                etemp.append(['TV','Onida','50-inch',q,price[2][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0       
            else:
                print("\nInvalid choice")
                electronics()   
                
     # ----------SAMSUNG TV----------------------------------------------------              
                
        elif y=='3':
            print("\n....SAMSUNG....")
            price=[['12-inch',10000],['24-inch',25000],['32-inch',28000]]
            for i in price:
                print(i)
            print("\n1. 12-inch",'2. 24-inch','3. 32-inch',sep='\n')
            a=input("Select the size of SAMSUNG tv")
            if a=='1':
                print("\nYou have selected 12-inch Onida TV")
                print("Rs.",price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[0][1])
                electronic_price.append(total_e)
                etemp.append(['TV','SAMSUNG','12-inch',q,price[0][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
                    
            elif a=='2':
                print("\nYou have selected 24-inch Samsung TV")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[1][1])
                electronic_price.append(total_e)
                etemp.append(['TV','Samsung','24-inch',q,price[1][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='3':
                print("\nYou have selected 32-inch Samsung TV")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[2][1])
                electronic_price.append(total_e)
                etemp.append(['TV','Samsung','32-inch',q,price[2][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0   
                
                
      #---------LG TV-------------------------------------------------------------------

        elif y=='4':
            print("\n....LG....")
            price=[['20-inch',18000],['30-inch',28000],['50-inch',48000]]
            for i in price:
                print(i)
            print("\n1. 20-inch",'2. 30-inch','3. 50-inch',sep='\n')
            a=input("Select the size of LG tv")
            if a=='1':
                print("\nYou have selected 20-inch LG TV")
                print("Rs.",price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[0][1])
                electronic_price.append(total_e)
                etemp.append(['TV','LG','20-inch',q,price[0][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
                    
            elif a=='2':
                print("\nYou have selected 30-inch LG TV")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[1][1])
                electronic_price.append(total_e)
                etemp.append(['TV','LG','30-inch',q,price[1][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='3':
                print("\nYou have selected 50-inch LG TV")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[2][1])
                electronic_price.append(total_e)
                etemp.append(['TV','LG','50-inch',q,price[2][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0        
            else:
                print("\nInvalid choice")
                electronics()
                
        else:
            print("\nInvalid choice")
            electronics()
            
            
#---------MOBILE-----------------------------------------------------------------------------                
                
    elif z=='2':
        print("\n....BRAND....")
        print("1.ONE PLUSE\n2.APPLE\n3.SAMSUNG")
        y=input("\nPlease select the brand:")
        
    #------ONE PLUSE MOBILE----------------------------------------------------------------
        if y=='1':
            print("\n....ONE PLUSE....")
            price=[['one_pluse-7',34000],['one_pluse-7t',44000],['one_pluse-7pro',48000],['one_pluse-6',24000],['one_pluse-6t',30000]]
            for i in price:
                print(i)
            print("\n....MODEL....")    
            print("1.One_pluse_7\n2.One_pluse_7t\n3.One_pluse_7pro\n4.One_pluse_6\n5.One_pluse_6t")
            a=input("\nPlease select the model:")
            
            if a=='1':
                print("\nYou selected One Pluse 7")
                print("Rs.",price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[0][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','One Pluse','One Pluse 7',q,price[0][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='2':
                print("\nYou selected One Pluse 7t")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[1][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','One Pluse','One Pluse 7t',q,price[1][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='3':
                print("\nYou selected One Pluse 7pro")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[2][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','One Pluse','One Pluse 7pro',q,price[2][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0 
                    
            elif a=='4':
                print("\nYou selected One Pluse 6")
                print("Rs.",price[3][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[3][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','One Pluse','One Pluse 6',q,price[3][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0 
                    
            elif a=='5':
                print("\nYou selected One Pluse 6t")
                print("Rs.",price[4][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[4][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','One Pluse','One Pluse 6t',q,price[4][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0         
            else:
                print("\nInvalid choice")
                electronics()
                
                
    #------APPLE MOBILE----------------------------------------------------------------
        elif y=='2':
            print("\n....APPLE....")
            price=[['iphone-6',24000],['iphone-7',34000],['iphone-10',60000],['iphone-11',100000],['iphone-11pro',110000]]
            for i in price:
                print(i)
            print("\n....MODEL....")    
            print("1.iphone-6\n2.iphone-7\n3.iphone-10\n4.iphone-116\n5.iphone-11pro")
            a=input("\nPlease select the model:")
            
            if a=='1':
                print("\nYour choice is iphone-6")
                print("Rs.",price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[0][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','apple','iphone-6',q,price[0][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='2':
                print("\nYou selected iphone-7")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[1][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','apple','iphone-7',q,price[1][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='3':
                print("\nYou selected iphone-10")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[2][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','apple','iphone-10',q,price[2][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0 
                    
            elif a=='4':
                print("\nYou selected iphone-11")
                print("Rs.",price[3][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[3][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','apple','iphone-11',q,price[3][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0 
                    
            elif a=='5':
                print("\nYou selected iphone-11pro")
                print("Rs.",price[4][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[4][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','apple','apple-11pro',q,price[4][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0         
            else:
                print("\nInvalid choice")
                electronics()
                
                
      #------SAMSUNG MOBILE----------------------------------------------------------------
        elif y=='3':
            print("\n....SAMSUNG....")
            price=[['M30',14000],['A30',21000],['S10',60000],['Galaxy_N10',80000],['S20',70000]]
            for i in price:
                print(i)
            print("\n....MODEL....")    
            print("1.M30\n2.A30\n3.S10\n4.Galaxy_N10\n5.S20")
            a=input("\nPlease select the model:")
            
            if a=='1':
                print("\nYour choice is M30")
                print("Rs.",price[0][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[0][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','Samsung','M30',q,price[0][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='2':
                print("\nYou selected A30")
                print("Rs.",price[1][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[1][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','samsung','A30',q,price[1][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0
                    
            elif a=='3':
                print("\nYou selected S10")
                print("Rs.",price[2][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[2][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','samsung','S10',q,price[2][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0 
                    
            elif a=='4':
                print("\nYou selected Galaxy_N10")
                print("Rs.",price[3][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[3][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','samsung','galaxy_N10',q,price[3][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0 
                    
            elif a=='5':
                print("\nYou selected S20")
                print("Rs.",price[4][1])
                d=0
                while d==0:
                    q=input("\nPlease select the number of pieces(quantity):")
                    if q.isnumeric():
                        q=int(q)
                        e_quant+=q
                        d=1
                    else:
                        print('\nInvalid input')
                total_e=q*(price[4][1])
                electronic_price.append(total_e)
                etemp.append(['Mobile','samsung','S20',q,price[4][1],total_e])
                c=0
                while c==0:
                    s = input("\nWould you like to purchase more electronic items?..Y/N:")
                    if s.isalpha() and (s=='Y' or s=='y'):
                        electronics()
                        c=1
                    elif s.isalpha() and (s=='N' or s=='n'):
                        main()
                        c=1
                    else:
                        print('\nInvalid input')
                        c=0         
            else:
                print("\nInvalid choice")
                electronics()    
        else:
            print("\nInvalid choice")
            electronics()

    else:
        print("\nInvalid choice")
        electronics()
        
                       
                
#----------------------------------------------------------------------------------------------
def main():
    print("\nPlease select the category that you want to shop")
    #a=True
    #while a:
        #print("\n....Category....")
    print("1.Electronics\n2.Fashion\n3.Sports\n55.Cart\n56.Bill & exit\n57.Category")
    n=input("\nEnter your choice:")
    if n=='1':
        electronics()
    elif n=='2':
        fashion()
    elif n=='3':
        sports()
    elif n=='55':
        cart()
    elif n=='56':
        bill()
#        a=False
#        exit
    elif n=='57':
        main()
    else:
        print("\nPlease enter the valid option")
        main()
            


#----------------------------------------------------------------------------------------------

def enter_name():
    name=input("Enter your name:")
    print("\nWelcome to online shopping Mr/Ms.",name)
    main()
    
#--------------------------------------------------------------------------------------------------------    
s="ONLINE SHOPPING"
print(s.center(114,'*'))
c=0
enter_name()
# Out:
# *************************************************ONLINE SHOPPING**************************************************
# Enter your name:og
#
# Welcome to online shopping Mr/Ms. og
#
# Please select the category that you want to shop
# 1.Electronics
# 2.Fashion
# 3.Sports
# 55.Cart
# 56.Bill & exit
# 57.Category
#
# Enter your choice:1
#
# .....ELECTRONICS.....
# 1.TV
# 2.Mobile
#
# Please select item:2
#
# ....BRAND....
# 1.ONE PLUSE
# 2.APPLE
# 3.SAMSUNG
#
# Please select the brand:3
#
# ....SAMSUNG....
# ['M30', 14000]
# ['A30', 21000]
# ['S10', 60000]
# ['Galaxy_N10', 80000]
# ['S20', 70000]
#
# ....MODEL....
# 1.M30
# 2.A30
# 3.S10
# 4.Galaxy_N10
# 5.S20
#
# Please select the model:3
#
# You selected S10
# Rs. 60000
#
# Please select the number of pieces(quantity):2
#
# Would you like to purchase more electronic items?..Y/N:y
#
# .....ELECTRONICS.....
# 1.TV
# 2.Mobile
#
# Please select item:1
#
# ....BRAND....
# 1.ONE PLUSE
# 2.ONIDA
# 3.SAMSUNG
# 4.LG
#
# ...
